# %% [markdown]
# # 02 - Feature Engineering
# **Objective:** Clean the dataset, handle missing values, and convert categorical features to numeric for ML.

# %%
import pandas as pd

df = pd.read_csv("../data/raw/used_cars.csv")
df.head()
# Out:
#    make_year  mileage_kmpl  engine_cc fuel_type  owner_count  price_usd  \
# 0       2001          8.17       4000    Petrol            4    8587.64
# 1       2014         17.59       1500    Petrol            4    5943.50
# 2       2023         18.09       2500    Diesel            5    9273.58
# 3       2009         11.28        800    Petrol            1    6836.24
# 4       2005         12.23       1000    Petrol            2    4625.79
#
#        brand transmission  color service_history  accidents_reported  \
# 0  Chevrolet       Manual  White             NaN                   0
# 1      Honda       Manual  Black             NaN                   0
# 2        BMW    Automatic  Black            Full                   1
# 3    Hyundai       Manual   Blue            Full                   0
# 4     Nissan    Automatic    Red            Full                   0
#
#   insurance_valid
# 0              No
# 1             Yes
# 2             Yes
# 3             Yes
# 4             Yes

# %% [markdown]
# ### Handle Missing Values
# - Fill missing `service_history` with "Unknown"
# - Drop rows with missing critical numeric values

# %%
df['service_history'] = df['service_history'].fillna("Unknown")
df = df.dropna(subset=['mileage_kmpl', 'engine_cc', 'price_usd'])

# %% [markdown]
# ### Add New Features
# - `car_age` = 2026 - `make_year`
# - Drop `make_year` column

# %%
df['car_age'] = 2026 - df['make_year']
df = df.drop(columns=['make_year'])

# %% [markdown]
# ### Convert Categorical Columns to Numeric
# We will use one-hot encoding for:
# - brand
# - fuel_type
# - transmission
# - service_history

# %%
categorical_cols = ["brand", "fuel_type", "transmission", "service_history"]
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=False)
df_encoded.head()
# Out:
#    mileage_kmpl  engine_cc  owner_count  price_usd  color  accidents_reported  \
# 0          8.17       4000            4    8587.64  White                   0
# 1         17.59       1500            4    5943.50  Black                   0
# 2         18.09       2500            5    9273.58  Black                   1
# 3         11.28        800            1    6836.24   Blue                   0
# 4         12.23       1000            2    4625.79    Red                   0
#
#   insurance_valid  car_age  brand_BMW  brand_Chevrolet  ...  brand_Toyota  \
# 0              No       25      False             True  ...         False
# 1             Yes       12      False            False  ...         False
# 2             Yes        3       True            False  ...         False
# 3             Yes       17      False            False  ...         False
# 4             Yes       21      False            False  ...         False
#
#    brand_Volkswagen  fuel_type_Diesel  fuel_type_Electric  fuel_type_Petrol  \
# 0             False             False               False              True
# 1             False             False               False              True
# 2             False              True               False             False
# 3             False             False               False              True
# 4             False             False               False              True
#
#    transmission_Automatic  transmission_Manual  service_history_Full  \
# 0                   False                 True                 False
# 1                   False                 True                 False
# 2                    True                False                  True
# 3                   False                 True                  True
# 4                    True                False                  True
#
#    service_history_Partial  service_history_Unknown
# 0                    False                     True
# 1                    False                     True
# 2                    False                    False
# 3                    False                    False
# 4                    False                    False
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Save Processed Data
# We save this dataset for training.

# %%
df_encoded.to_csv("../data/processed/cleaned_data.csv", index=False)
